# %%
# %pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in C:\Users\Nomalanga\AppData\Local\Programs\Python\Python313\Lib\site-packages (3.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\Nomalanga\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\Nomalanga\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\Nomalanga\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\Nomalanga\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.25 in C:\Users\Nomalanga\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib) (2.2.4)
# Requirement already satisfied: packaging>=20.0 in C:\Users\Nomalanga\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=9 in C:\Users\Nomalanga\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\Nomalanga\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\Nomalanga\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in C:\Users\Nomalanga\AppData\Local\Programs\Python\Python313\Lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import pyarrow as pa


print(pd.__version__)
print(pa.__version__)
# Out:
# 3.0.3
# 25.0.0

# %%
taxi_df = pd.read_parquet("Data/yellow_tripdata_2019-01.parquet")

# %%
taxi_df.columns
# Out:
# Index(['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
#        'passenger_count', 'trip_distance', 'RatecodeID', 'store_and_fwd_flag',
#        'PULocationID', 'DOLocationID', 'payment_type', 'fare_amount', 'extra',
#        'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge',
#        'total_amount', 'congestion_surcharge', 'airport_fee'],
#       dtype='str')

# %%
import numpy as np

# %%
taxi_df = taxi_df[['tpep_pickup_datetime', 'tpep_dropoff_datetime', 'passenger_count', 'trip_distance', 'RatecodeID', 'PULocationID', 'DOLocationID', 'payment_type', 'total_amount']]

# %%
taxi_df.head()
# Out:
#   tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  trip_distance  \
# 0  2019-01-01 00:46:40   2019-01-01 00:53:20              1.0            1.5
# 1  2019-01-01 00:59:47   2019-01-01 01:18:59              1.0            2.6
# 2  2018-12-21 13:48:30   2018-12-21 13:52:40              3.0            0.0
# 3  2018-11-28 15:52:25   2018-11-28 15:55:45              5.0            0.0
# 4  2018-11-28 15:56:57   2018-11-28 15:58:33              5.0            0.0
#
#    RatecodeID  PULocationID  DOLocationID  payment_type  total_amount
# 0         1.0           151           239             1          9.95
# 1         1.0           239           246             1         16.30
# 2         1.0           236           236             1          5.80
# 3         1.0           193           193             2          7.55
# 4         2.0           193           193             2         55.55

# %%
taxi_df.hist(figsize=(20,10), bins=60)
# Out:
# array([[<Axes: title={'center': 'tpep_pickup_datetime'}>,
#         <Axes: title={'center': 'tpep_dropoff_datetime'}>,
#         <Axes: title={'center': 'passenger_count'}>],
#        [<Axes: title={'center': 'trip_distance'}>,
#         <Axes: title={'center': 'RatecodeID'}>,
#         <Axes: title={'center': 'PULocationID'}>],
#        [<Axes: title={'center': 'DOLocationID'}>,
#         <Axes: title={'center': 'payment_type'}>,
#         <Axes: title={'center': 'total_amount'}>]], dtype=object)

# %%
taxi_df['RatecodeID'].value_counts()
# Out:
# RatecodeID
# 1.0     7430288
# 2.0      166093
# 5.0       54570
# 3.0       11801
# 4.0        4895
# 99.0        252
# 6.0          46
# Name: count, dtype: int64

# %%
taxi_df.reset_index().plot(kind='scatter', y='total_amount', x='index', figsize=(10,5))
# Out:
# <Axes: xlabel='index', ylabel='total_amount'>

# %%
taxi_df[taxi_df['total_amount']<1000].reset_index().plot(kind='scatter', y='total_amount',x='index',figsize=(10,5))
# Out:
# <Axes: xlabel='index', ylabel='total_amount'>

# %%
print(taxi_df[taxi_df['total_amount']<0].shape)
taxi_df[taxi_df['total_amount']<0].reset_index().plot(kind='scatter', y='total_amount', x='index', figsize=(10,5))
# Out:
# (7127, 9)
# <Axes: xlabel='index', ylabel='total_amount'>

# %%
taxi_df[taxi_df['total_amount']<0].head()
# Out:
#      tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 663   2019-01-01 00:32:56   2019-01-01 00:33:35              2.0
# 2402  2019-01-01 00:14:18   2019-01-01 00:40:55              1.0
# 2541  2019-01-01 00:31:27   2019-01-01 00:42:39              1.0
# 2544  2019-01-01 00:45:57   2019-01-01 00:46:07              1.0
# 2547  2019-01-01 00:48:35   2019-01-01 00:49:59              1.0
#
#       trip_distance  RatecodeID  PULocationID  DOLocationID  payment_type  \
# 663            0.10         1.0           148           148             3
# 2402           4.13         1.0           170           238             4
# 2541           1.35         1.0           162           234             4
# 2544           0.00         1.0           234           234             4
# 2547           0.16         1.0           234           234             4
#
#       total_amount
# 663           -3.8
# 2402         -20.3
# 2541          -9.8
# 2544          -3.8
# 2547          -4.3

# %%
taxi_df[taxi_df['total_amount']<0]['payment_type'].value_counts()
# Out:
# payment_type
# 3    4083
# 4    2667
# 2     376
# 1       1
# Name: count, dtype: int64

# %%
taxi_df[taxi_df['total_amount']<0]['trip_distance'].hist(bins=60, figsize=(10,5))
# Out:
# <Axes: >

# %%
print(taxi_df[taxi_df['total_amount']==0].shape)
taxi_df[taxi_df['total_amount']==0].head()
# Out:
# (1643, 9)
#       tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 3552   2019-01-01 00:18:46   2019-01-01 00:18:46              1.0
# 9138   2019-01-01 00:41:47   2019-01-01 00:41:47              1.0
# 13256  2019-01-01 00:19:38   2019-01-01 00:20:35              1.0
# 13257  2019-01-01 00:43:34   2019-01-01 00:43:34              1.0
# 13258  2019-01-01 00:02:52   2019-01-01 00:02:52              1.0
#
#        trip_distance  RatecodeID  PULocationID  DOLocationID  payment_type  \
# 3552             0.0         5.0           186           264             2
# 9138             0.0         5.0           246           264             2
# 13256            0.0         1.0           193           193             1
# 13257            0.0         1.0             7             7             2
# 13258            0.0         1.0           264             7             2
#
#        total_amount
# 3552            0.0
# 9138            0.0
# 13256           0.0
# 13257           0.0
# 13258           0.0

# %%
taxi_df[taxi_df['total_amount']==0]['payment_type'].value_counts()
# Out:
# payment_type
# 1    813
# 2    569
# 0    231
# 3     29
# 4      1
# Name: count, dtype: int64

# %%
taxi_df[taxi_df['total_amount']==0]['trip_distance'].hist(bins=60, figsize=(10,5))
# Out:
# <Axes: >

# %%
taxi_df.reset_index().plot(kind='scatter', y='total_amount', x='index', figsize=(10,5))
# Out:
# <Axes: xlabel='index', ylabel='total_amount'>

# %%
taxi_df[taxi_df['total_amount']>500].shape
# Out:
# (56, 9)

# %%
taxi_df[taxi_df['total_amount']>200].shape
# Out:
# (1166, 9)

# %%
taxi_df_filtered = taxi_df[(taxi_df['total_amount']>0)&(taxi_df['total_amount']<200)]

# %%
taxi_df_filtered.shape
# Out:
# (7686676, 9)

# %%
taxi_df_filtered.isna().sum()
# Out:
# tpep_pickup_datetime         0
# tpep_dropoff_datetime        0
# passenger_count          28441
# trip_distance                0
# RatecodeID               28441
# PULocationID                 0
# DOLocationID                 0
# payment_type                 0
# total_amount                 0
# dtype: int64

# %%
missing_percentage = (taxi_df_filtered.isna().sum() / len(taxi_df_filtered)) * 100
print(missing_percentage)
# Out:
# tpep_pickup_datetime     0.000000
# tpep_dropoff_datetime    0.000000
# passenger_count          0.370004
# trip_distance            0.000000
# RatecodeID               0.370004
# PULocationID             0.000000
# DOLocationID             0.000000
# payment_type             0.000000
# total_amount             0.000000
# dtype: float64

# %%
taxi_df_filtered = taxi_df_filtered.dropna(
    subset=["passenger_count", "RatecodeID"]
)
