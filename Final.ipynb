# %%
import pandas as pd

# %%
taxi_df = pd.read_parquet("Data/yellow_tripdata_2019-01.parquet")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 taxi_df = pd.read_parquet("Data/yellow_tripdata_2019-01.parquet")
#       2
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parquet.py:668, in read_parquet(path, engine, columns, storage_options, dtype_backend, filesystem, filters, to_pandas_kwargs, **kwargs)
#     508 @set_module("pandas")
#     509 def read_parquet(
#     510     path: FilePath | ReadBuffer[bytes],
#    (...)    518     **kwargs,
#     519 ) -> DataFrame:
#     520     """
#     521     Load a parquet object from the file path, returning a DataFrame.
#     522
#    (...)    665     1    4    9
#     666     """
# --> 668     impl = get_engine(engine)
#     669     check_dtype_backend(dtype_backend)
#     671     return impl.read(
#     672         path,
#     673         columns=columns,
#    (...)    679         **kwargs,
#     680     )
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parquet.py:68, in get_engine(engine)
#      65         except ImportError as err:
#      66             error_msgs += "\n - " + str(err)
# ---> 68     raise ImportError(
#      69         "Unable to find a usable engine; "
#      70         "tried using: 'pyarrow', 'fastparquet'.\n"
#      71         "A suitable version of "
#      72         "pyarrow or fastparquet is required for parquet "
#      73         "support.\n"
#      74         "Trying to import the above resulted in these errors:"
#      75         f"{error_msgs}"
#      76     )
#      78 if engine == "pyarrow":
#      79     return PyArrowImpl()
#
# ImportError: Unable to find a usable engine; tried using: 'pyarrow', 'fastparquet'.
# A suitable version of pyarrow or fastparquet is required for parquet support.
# Trying to import the above resulted in these errors:
#  - `Import pyarrow` failed. pyarrow is required for parquet support. Use pip or conda to install the pyarrow package.
#  - `Import fastparquet` failed. fastparquet is required for parquet support. Use pip or conda to install the fastparquet package.

# %%
pip install pyarrow
# Out:
# Collecting pyarrow
#   Downloading pyarrow-25.0.0-cp313-cp313-win_amd64.whl.metadata (3.0 kB)
# Downloading pyarrow-25.0.0-cp313-cp313-win_amd64.whl (27.9 MB)
#    ---------------------------------------- 0.0/27.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/27.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/27.9 MB ? eta -:--:--
#    ---------------------------------------- 0.3/27.9 MB ? eta -:--:--
#     --------------------------------------- 0.5/27.9 MB 957.6 kB/s eta 0:00:29
#    - -------------------------------------- 1.0/27.9 MB 1.7 MB/s eta 0:00:16
#    --- ------------------------------------ 2.4/27.9 MB 3.0 MB/s eta 0:00:09
#    ---- ----------------------------------- 2.9/27.9 MB 3.3 MB/s eta 0:00:08
#    ---- ----------------------------------- 3.4/27.9 MB 2.9 MB/s eta 0:00:09
#    ------ --------------------------------- 4.2/27.9 MB 2.7 MB/s eta 0:00:09
#    ------ --------------------------------- 4.5/27.9 MB 2.6 MB/s eta 0:00:10
#    ------ --------------------------------- 4.7/27.9 MB 2.5 MB/s eta 0:00:10
#    ------- -------------------------------- 5.0/27.9 MB 2.4 MB/s eta 0:00:10
#    ------- -------------------------------- 5.5/27.9 MB 2.4 MB/s eta 0:00:10
#    -------- ------------------------------- 6.0/27.9 MB 2.3 MB/s eta 0:00:10
#    -------- ------------------------------- 6.0/27.9 MB 2.3 MB/s eta 0:00:10
#    --------- ------------------------------ 6.3/27.9 MB 2.1 MB/s eta 0:00:11
#    ---------- ----------------------------- 7.6/27.9 MB 2.4 MB/s eta 0:00:09
#    ----------- ---------------------------- 8.1/27.9 MB 2.4 MB/s eta 0:00:09
#    ------------ --------------------------- 8.7/27.9 MB 2.4 MB/s eta 0:00:09
#    ------------ --------------------------- 8.7/27.9 MB 2.4 MB/s eta 0:00:09
#    ------------- -------------------------- 9.4/27.9 MB 2.3 MB/s eta 0:00:08
#    --------------- ------------------------ 10.5/27.9 MB 2.4 MB/s eta 0:00:08
#    ---------------- ----------------------- 11.5/27.9 MB 2.6 MB/s eta 0:00:07
#    ------------------ --------------------- 12.8/27.9 MB 2.7 MB/s eta 0:00:06
#    ------------------- -------------------- 13.9/27.9 MB 2.8 MB/s eta 0:00:05
#    -------------------- ------------------- 14.2/27.9 MB 2.8 MB/s eta 0:00:05
#    ----------------------- ---------------- 16.3/27.9 MB 3.0 MB/s eta 0:00:04
#    ----------------------- ---------------- 16.5/27.9 MB 3.0 MB/s eta 0:00:04
#    ------------------------- -------------- 17.6/27.9 MB 3.1 MB/s eta 0:00:04
#    -------------------------- ------------- 18.6/27.9 MB 3.1 MB/s eta 0:00:03
#    --------------------------- ------------ 19.1/27.9 MB 3.1 MB/s eta 0:00:03
#    ---------------------------- ----------- 19.9/27.9 MB 3.1 MB/s eta 0:00:03
#    ----------------------------- ---------- 20.4/27.9 MB 3.1 MB/s eta 0:00:03
#    ------------------------------ --------- 21.2/27.9 MB 3.1 MB/s eta 0:00:03
#    ------------------------------- -------- 22.0/27.9 MB 3.1 MB/s eta 0:00:02
#    -------------------------------- ------- 22.5/27.9 MB 3.1 MB/s eta 0:00:02
#    --------------------------------- ------ 23.3/27.9 MB 3.1 MB/s eta 0:00:02
#    ---------------------------------- ----- 24.1/27.9 MB 3.1 MB/s eta 0:00:02
#    ----------------------------------- ---- 24.6/27.9 MB 3.1 MB/s eta 0:00:02
#    ----------------------------------- ---- 24.9/27.9 MB 3.0 MB/s eta 0:00:01
#    ------------------------------------- -- 26.2/27.9 MB 3.1 MB/s eta 0:00:01
#    -------------------------------------- - 26.7/27.9 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  27.3/27.9 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  27.8/27.9 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  27.8/27.9 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  27.8/27.9 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  27.8/27.9 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  27.8/27.9 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  27.8/27.9 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  27.8/27.9 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  27.8/27.9 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  27.8/27.9 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  27.8/27.9 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  27.8/27.9 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  27.8/27.9 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  27.8/27.9 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  27.8/27.9 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  27.8/27.9 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  27.8/27.9 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  27.8/27.9 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  27.8/27.9 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  27.8/27.9 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  27.8/27.9 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  27.8/27.9 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  27.8/27.9 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  27.8/27.9 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  27.8/27.9 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  27.8/27.9 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  27.8/27.9 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  27.8/27.9 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  27.8/27.9 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  27.8/27.9 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  27.8/27.9 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  27.8/27.9 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  27.8/27.9 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  27.8/27.9 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  27.8/27.9 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  27.8/27.9 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  27.8/27.9 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  27.8/27.9 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  27.8/27.9 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  27.8/27.9 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  27.8/27.9 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  27.8/27.9 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  27.8/27.9 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  27.8/27.9 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  27.8/27.9 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  27.8/27.9 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  27.8/27.9 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  27.8/27.9 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  27.8/27.9 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  27.8/27.9 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  27.8/27.9 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  27.8/27.9 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  27.8/27.9 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  27.8/27.9 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  27.8/27.9 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  27.8/27.9 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  27.8/27.9 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  27.8/27.9 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  27.8/27.9 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  27.8/27.9 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  27.8/27.9 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  27.8/27.9 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------- 27.9/27.9 MB 1.2 MB/s  0:00:22
# Installing collected packages: pyarrow
# Successfully installed pyarrow-25.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
taxi_df = pd.read_parquet("Data/yellow_tripdata_2019-01.parquet")

# %%
taxi_df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2019-01-01 00:46:40   2019-01-01 00:53:20              1.0
# 1         1  2019-01-01 00:59:47   2019-01-01 01:18:59              1.0
# 2         2  2018-12-21 13:48:30   2018-12-21 13:52:40              3.0
# 3         2  2018-11-28 15:52:25   2018-11-28 15:55:45              5.0
# 4         2  2018-11-28 15:56:57   2018-11-28 15:58:33              5.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0            1.5         1.0                  N           151           239
# 1            2.6         1.0                  N           239           246
# 2            0.0         1.0                  N           236           236
# 3            0.0         1.0                  N           193           193
# 4            0.0         2.0                  N           193           193
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0             1          7.0    0.5      0.5        1.65           0.0
# 1             1         14.0    0.5      0.5        1.00           0.0
# 2             1          4.5    0.5      0.5        0.00           0.0
# 3             2          3.5    0.5      0.5        0.00           0.0
# 4             2         52.0    0.0      0.5        0.00           0.0
#
#    improvement_surcharge  total_amount  congestion_surcharge airport_fee
# 0                    0.3          9.95                   NaN        None
# 1                    0.3         16.30                   NaN        None
# 2                    0.3          5.80                   NaN        None
# 3                    0.3          7.55                   NaN        None
# 4                    0.3         55.55                   NaN        None

# %%
taxi_df.shape
# Out:
# (7696617, 19)
